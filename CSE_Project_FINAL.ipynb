# %%
from tkinter import *
from tkinter import ttk
import random
import time
import datetime
import tkinter.messagebox

def hotel():
    print("Hotel Available:")
    print("Radisson Blu Hotel(5 Star)")
    print("Le Grand Regency(3 Star)")
    print("Grand Heritage Resort(2 Star)")
    ch=int(input("Enter your hotel choice:"))


def radi_p():
    root1=Tk()
    frame=Frame(root1, bg="light blue")
  
    
    label_1=Label(frame,text="Facilities Available:", font=("times",12,'bold'))
    label_2=Label(frame,text="Enjoy 5 star spa facilities")
    label_3=Label(frame,text="Swimming pool")
    label_4=Label(frame,text="Gym: Equipped with Technogym equipment, our Fitness Studio provides a convenient and comfortable workout atmosphere.")
    label_5=Label(frame,text="Sauna rondello: Heated to a temperature of 80 to 100 ˚C with minimal humidity, the sauna treats guests to a dry, intense heat.")
    label_6=Label(frame,text="Soothing showers: Experience our specially designed showers and choose from warm tropical rainfall that cascades down on you or a refreshing and invigorating cold mist that revives your entire body.")
    
    button_1= Button(frame, text="Book Now",bg="yellow",command=book_now)
    frame.pack()
    label_1.pack()
    label_2.pack()
    label_3.pack()
    label_4.pack()
    label_5.pack()
    label_6.pack()
    button_1.pack()
    
    root1.mainloop()
    



def le_pi():
    root2=Tk()
    frame=Frame(root2, bg="light blue")
    frameb=Frame(root2, bg="light blue")
    label_1=Label(frame,text="Facilities Available:", font=("times",12,'bold'))
    label_2=Label(frame,text="Enjoy 3 star spa facilities", font="times")
    label_3=Label(frame,text="Swimming pool", font="times")
    label_4=Label(frame,text="Food and Drink buffet", font="times")
    label_5=Label(frame,text="Free wifi", font="times")
    label_6=Label(frame,text="Free Parking", font="times")
    button_1= Button(frame, text="Book Now",bg="yellow", command=book_now)
    frame.pack(fill=BOTH)
    label_1.pack()
    label_2.pack()
    label_3.pack()
    label_4.pack()
    label_5.pack()
    label_6.pack()
    button_1.pack()
    frameb.pack(side=BOTTOM, fill=Y)
    root2.mainloop()



    
    #button for booking 
def he_pi():
    root3=Tk()
    frame=Frame(root3, bg="light blue")
    frameb=Frame(root3, bg="light blue")
    label_1=Label(frame,text="Facilities Available:", font=("times",12,'bold'))
    label_2=Label(frame,text="Enjoy 3 star spa facilities", font="times")
    label_3=Label(frame,text="Golf Course(within 3kms)(Additional charge)", font="times")
    label_4=Label(frame,text="Food and Drink buffet", font="times")
    label_5=Label(frame,text="Free wifi", font="times")
    label_6=Label(frame,text="Free Parking", font="times")
    button_1= Button(frame, text="Book Now",bg="yellow", command=book_now)
    frame.pack(fill=BOTH)
    label_1.pack()
    label_2.pack()
    label_3.pack()
    label_4.pack()
    label_5.pack()
    label_6.pack()
    button_1.pack()
    frameb.pack(side=BOTTOM, fill=Y)
    root3.mainloop()
    
    #button for booking

def delux_room():
    root5=Tk()

    C = Canvas(root5, bg="blue", height=250, width=300)
    image = PhotoImage(file = "radisson.png")
    background_label = Label(root5, image=image)
    background_label.place(x=0, y=0, relwidth=1, relheight=1)
    label=Label(root5,text="Delux Twin Room",fg="red", font="times")

    label.pack()
    C.pack()

    root5.mainloop()




class HippoHotels:
    def __init__(self,root):
        self.root = root
        self.root.title("HIPPOHOTELS BOOKING")
        self.root.geometry("1350x750+0+0")
        self.root.configure(background='cyan')
        
        
        cmRoomChosen=StringVar()
        FirstName=StringVar()
        NoofRooms=StringVar()
        NoofAdults=StringVar()
        CheckIn=StringVar()
        BuffetNeeded=StringVar()
        TranspNeeded=StringVar()
        Event=StringVar()
        Address=StringVar()
        ContactNo=StringVar()
        LastName=StringVar()
        EmailId=StringVar()
        NoofChildren=StringVar()
        CheckOut=StringVar()
        CustomerAge=StringVar()
        Password=StringVar()
        TourGuide=StringVar()
        FeedBack=StringVar()
        Prescription=StringVar()    

        
        #=============================================Function Declaration============================================#
        
        
        def iExit():
            iExit=tkinter.messagebox.askyesno("HIPPOHOTELS BOOKING","Confirm if you want to exit")
            if iExit >0:
                root.destroy()
                return

        def iDetailsEntered():
            
            self.txtPrescription.insert(END, "First Name: "+ FirstName.get() + "\n")
            self.txtPrescription.insert(END, "Last Name: "+ LastName.get() + "\n")   
            self.txtPrescription.insert(END, "Customer Age: "+ CustomerAge.get() + "\n")   
            self.txtPrescription.insert(END, "Room Chosen: "+ cmRoomChosen.get() + "\n")   
            self.txtPrescription.insert(END, "No of rooms: "+ NoofRooms.get() + "\n")     
            self.txtPrescription.insert(END, "Check in Date(DD/MM/YY): "+ CheckIn.get() + "\n")   
            self.txtPrescription.insert(END, "Check out Date(DD/MM/YY): "+ CheckOut.get() + "\n")   
            self.txtPrescription.insert(END, "Email-id: "+ EmailId.get() + "\n")    
            self.txtPrescription.insert(END, "No of Adults: "+ NoofAdults.get() + "\n")     
            self.txtPrescription.insert(END, "No of children: "+ NoofChildren.get() + "\n")   
            
            return

        def iCustomerData():

            self.txtFrameDetail.insert(END, cmRoomChosen.get() + "\t" + "\t" + FirstName.get() +"\t"+"\t" +NoofRooms.get()+"\t"+"\t" +NoofAdults.get()+"\t" +"\t"
            +CheckIn.get()+"\t"+"\t"+ BuffetNeeded.get()+"\t"+"\t" + TranspNeeded.get()+"\t"+"\t"+ Event.get()+"\t"+"\t"+ LastName.get()+"\t"+"\t"+ 
            CustomerAge.get()+"\t"+ "\t"+  Password.get()+ "\n")


            return

        def iDelete():

            cmRoomChosen.set("")
            self.cboRoomChosen.current(0)
            FirstName.set("")
            NoofRooms.set("")
            NoofAdults.set("")
            CheckIn.set("")
            BuffetNeeded.set("")
            TranspNeeded.set("")
            Event.set("")
            Address.set("")
            ContactNo.set("")
            LastName.set("")
            EmailId.set("")
            NoofChildren.set("")
            CheckOut.set("")
            CustomerAge.set("")
            Password.set("")
            TourGuide.set("")
            FeedBack.set("")
            self.txtPrescription.delete("1.0",END)
            self.txtFrameDetail.delete("1.0",END)


            return

        def iReset():


            cmRoomChosen.set("")
            self.cboRoomChosen.current(0)
            FirstName.set("")
            NoofRooms.set("")
            NoofAdults.set("")
            CheckIn.set("")
            BuffetNeeded.set("")
            TranspNeeded.set("")
            Event.set("")
            Address.set("")
            ContactNo.set("")
            LastName.set("")
            EmailId.set("")
            NoofChildren.set("")
            CheckOut.set("")
            CustomerAge.set("")
            Password.set("")
            TourGuide.set("")
            FeedBack.set("")
            self.txtPrescription.delete("1.0",END)
            self.txtFrameDetail.delete("1.0",END)

            return



        
        #=====================================================Frame====================================================#
        #inko samajhna hai
        MainFrame=Frame(self.root)
        MainFrame.grid()
        
        TitleFrame=Frame(MainFrame, bd=20, width=1350, padx=20, relief=RIDGE)
        TitleFrame.pack(side=TOP)
        
        self.lblTitle=Label(TitleFrame, font=('Arial Black', 37, 'bold'), text='HIPPOHOTELS BOOKING',fg='navy', padx=2)
        self.lblTitle.grid()
        
        FrameDetail = Frame(MainFrame, bd=20, width=1350, height=100, padx=20, relief=RIDGE)
        FrameDetail.pack(side=BOTTOM)
        
        ButtonFrame = Frame(MainFrame, bd=20, width=1350, height=50, padx=20, relief=RIDGE)
        ButtonFrame.pack(side=BOTTOM)
        
        DataFrame = Frame(MainFrame, bd=20, width=1350, height=400, padx=20, relief=RIDGE)
        DataFrame.pack(side=BOTTOM)
        
        DataFrameLEFT = LabelFrame(DataFrame, bd=10, width=900, height=300, padx=20, relief=RIDGE, font=('Arial', 11, 'bold'), 
                             text='CUSTOMER DETAILS')
        DataFrameLEFT.pack(side=LEFT)
        
        DataFrameRIGHT = LabelFrame(DataFrame, bd=10, width=455, height=300, padx=20, relief=RIDGE
                                   , font=('Arial', 11, 'bold'), text='DETAILS ENTERED:')
        DataFrameRIGHT.pack(side=RIGHT)
        
        #================================================DataFrameLEFT================================================#
        
        self.lblRoomChosen=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Room Chosen:', fg='mediumblue',padx=2, pady=2)
        self.lblRoomChosen.grid(row=0, column=0, sticky=W)
        
        self.cboRoomChosen=ttk.Combobox(DataFrameLEFT, textvariable= cmRoomChosen, state='readonly', 
                                        font=('Arial', 10, 'bold'), width=20)
        self.cboRoomChosen['value']=('','Deluxe Twin Room ', 'Super Deluxe Double Room', 'Deluxe Single Room', 'Executive Double Room')
        self.cboRoomChosen.current(0)
        self.cboRoomChosen.grid(row=0, column=1)
        
        self.lblContactNumber=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Contact Number:', fg='mediumblue',padx=2, pady=2)
        self.lblContactNumber.grid(row=0, column=2, sticky=W)
        
        self.txtContactNumber=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=ContactNo, width=25)
        self.txtContactNumber.grid(row=0, column=3)
        
        self.lblFirstName=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='First Name:',fg='mediumblue', padx=2, pady=2)
        self.lblFirstName.grid(row=1, column=0, sticky=W)
        
        self.txtFirstName=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=FirstName, width=25)
        self.txtFirstName.grid(row=1, column=1)
        
        self.lblLastName=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Last Name:', fg='mediumblue',padx=2, pady=2)
        self.lblLastName.grid(row=1, column=2, sticky=W)
        
        self.txtLastName=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=LastName, width=25)
        self.txtLastName.grid(row=1, column=3)
        
        self.lblNoofRooms=Label(DataFrameLEFT, font=('Arail', 11, 'bold'), text='No of Rooms:', fg='mediumblue',padx=2, pady=2)
        self.lblNoofRooms.grid(row=2, column=0, sticky=W)
        
        self.txtNoofRooms=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=NoofRooms, width=25)
        self.txtNoofRooms.grid(row=2, column=1)
        
        self.lblEmailId=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Email-Id:',fg='mediumblue', padx=2, pady=2)
        self.lblEmailId.grid(row=2, column=2, sticky=W)
        
        self.txtEmailId=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=EmailId, width=25)
        self.txtEmailId.grid(row=2, column=3)
        
        self.lblNoOfAdults=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='No. of Adults:', fg='mediumblue',padx=2, pady=2)
        self.lblNoOfAdults.grid(row=3, column=0, sticky=W)
        self.txtNoOfAdults=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=NoofAdults, width=25)
        self.txtNoOfAdults.grid(row=3, column=1) 
        
        self.lblNoOfChildren=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='No of Children:',fg='mediumblue', padx=2, pady=2)
        self.lblNoOfChildren.grid(row=3, column=2, sticky=W)
        
        self.txtNoOfChildren=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=NoofChildren, width=25)
        self.txtNoOfChildren.grid(row=3, column=3)
        
        self.lblCheckIn=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Check In Date:',fg='mediumblue', padx=2, pady=2)
        self.lblCheckIn.grid(row=4, column=0, sticky=W)
        
        self.txtCheckIn=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=CheckIn, width=25)
        self.txtCheckIn.grid(row=4, column=1)
        
        self.lblCheckOut=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Check Out Date:',fg='mediumblue', padx=2, pady=2)
        self.lblCheckOut.grid(row=4, column=2, sticky=W)
        
        self.txtCheckOut=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=CheckOut, width=25)
        self.txtCheckOut.grid(row=4, column=3)
        
        self.lblBuffetNeeded=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Buffet Needed(Y/N):', fg='mediumblue',padx=2, pady=2)
        self.lblBuffetNeeded.grid(row=5, column=0, sticky=W)
        
        self.txtBuffetNeeded=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=BuffetNeeded, width=25)
        self.txtBuffetNeeded.grid(row=5, column=1)
        
        self.lblTranspNeeded=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Transportation Needed(Y/N):', fg='mediumblue',padx=2, pady=2)
        self.lblTranspNeeded.grid(row=5, column=2, sticky=W)
        
        self.txtTranspNeeded=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=TranspNeeded, width=25)
        self.txtTranspNeeded.grid(row=5, column=3)
        
        self.lblPassword=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Password:',fg='mediumblue', padx=2, pady=2)
        self.lblPassword.grid(row=6, column=0, sticky=W)
        
        self.txtPassword=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=Password, width=25)
        self.txtPassword.grid(row=6, column=1)
        
        self.lblCustomerAge=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Customer Age:',fg='mediumblue', padx=2, pady=2)
        self.lblCustomerAge.grid(row=6, column=2, sticky=W)
        
        self.txtCustomerAge=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=CustomerAge, width=25)
        self.txtCustomerAge.grid(row=6, column=3)
        
        self.lblEvent=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Event(Stay/Marriage/Other):', fg='mediumblue',padx=2, pady=2)
        self.lblEvent.grid(row=7, column=0, sticky=W)
        
        self.txtEvent=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=Event, width=25)
        self.txtEvent.grid(row=7, column=1)
        
        self.lblTourGuide=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Tour Guide(Yes/No):', fg='mediumblue',padx=2, pady=2)
        self.lblTourGuide.grid(row=7, column=2, sticky=W)
        
        self.txtTourGuide=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=TourGuide, width=25)
        self.txtTourGuide.grid(row=7, column=3)
        
        self.lblAddress=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='Address:',fg='mediumblue', padx=2, pady=2)
        self.lblAddress.grid(row=8, column=0, sticky=W)
        
        self.txtAddress=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=Address, width=25)
        self.txtAddress.grid(row=8, column=1)
        
        self.lblFeedBack=Label(DataFrameLEFT, font=('Arial', 11, 'bold'), text='FeedBack:',fg='mediumblue',padx=2, pady=2)
        self.lblFeedBack.grid(row=8, column=2, sticky=W)
        
        self.txtFeedBack=Entry(DataFrameLEFT, font=('Arial', 11, 'bold'), textvariable=FeedBack, width=25)
        self.txtFeedBack.grid(row=8, column=3)
        
        
        #==================================================DataFrameRIGHT================================================#
        
        
        
        self.txtPrescription=Text(DataFrameRIGHT, font=('Arial', 11, 'bold'),width=40,height=10, padx=2, pady=6)
        self.txtPrescription.grid(row=0, column=0)
        
        
        #==================================================ButtonFrame===============================================#
        
        self.btnPrescription=Button(ButtonFrame, text='Details Entered',font=('Arial', 11, 'bold'), fg='deeppink',width=24, bd=4, 
                                    command=iDetailsEntered)
        self.btnPrescription.grid(row=0, column=0)
        
        self.btnPrescriptionData=Button(ButtonFrame, text='Customer Data',font=('Arial', 11, 'bold'),fg='deeppink', width=24, bd=4,
                              command=iCustomerData)
        self.btnPrescriptionData.grid(row=0, column=1)
        
        self.btnDelete=Button(ButtonFrame, text='Delete',font=('Arial', 11, 'bold'),fg='deeppink', width=24, bd=4,
                             command=iDelete)
        self.btnDelete.grid(row=0, column=2)
        
        
        self.btnReset=Button(ButtonFrame, text='Reset',font=('Arial', 11, 'bold'), fg='deeppink',width=24, bd=4,
                            command=iReset)
        self.btnReset.grid(row=0, column=3)
        
        
        self.btnExit=Button(ButtonFrame, text='Exit',font=('Arial', 11, 'bold'), fg='deeppink',width=24, bd=4, command=iExit)
        self.btnExit.grid(row=0, column=4)
        
        
        #==================================================FrameDetail================================================#
        
        
        self.lblLabel=Label(FrameDetail, font=('Arial', 10, 'bold'), pady=6, 
        text="Room Chosen\tFirstName\tNo of Rooms\tNo.of Adults \tCheck-In Date\tBuffet Needed\tTransportation Needed\t Event\tLastName\tPassword\tAge")
        self.lblLabel.grid(row=0, column=0)
        
        self.txtFrameDetail=Text(FrameDetail, font=('calibri', 11, 'bold'),width=164, height=4, padx=2, pady=2)
        self.txtFrameDetail.grid(row=1, column=0)
        
        
        
        
def book_now():
    if __name__=='__main__':
        root=Tk()
        application=HippoHotels(root)
        root.mainloop()




def Book():
    root_new1=Tk()

    frame=Frame(root_new1,bg="light blue")
    label_1 = Label(frame, text= "Booking Successful!")

    label_1.pack()
    frame.pack(fill=BOTH)
    
    
    root_new1.mainloop()
    

root= Tk()
frame=Frame(root, bg="light blue")

label= Label(frame,text="Hotels around bennett university", font= "times 24", bg="yellow", fg="blue")
label_1= Label(frame,text="Radisson blue Hotel(5 star)")
label_2= Label(frame,text="Le Grand Regency(3 Star)")
label_3= Label(frame,text="Grand Heritage Resort(2 Star)")
label_5= Label(frame, bg="yellow")
label_6= Label(frame, bg="yellow")

photo_1= PhotoImage(file='radisson.png')
photo_2= PhotoImage(file='legrand.png')
photo_3= PhotoImage(file='heritage.png')

button_1= Button(frame,image=photo_1, text="Radisson blue Hotel(5 star)",fg="white", command=radi_p,padx = 50)
button_2= Button(frame,image=photo_2, text="Le Grand Regency(3 Star)",fg="white", command= le_pi, padx = 50)
button_3= Button(frame,image=photo_3, text="Grand Heritage Resort(2 Star)",fg="white", command=he_pi, padx = 50)

frame.pack(fill=BOTH)
label.pack(fill=BOTH)
button_1.pack(pady = 5, padx = 50)
label_1.pack()
button_2.pack(pady =5, padx = 50)
label_2.pack()
button_3.pack(pady = 5, padx = 50)
label_3.pack()
label_5.pack(side=LEFT, fill=Y)
label_6.pack(side=RIGHT, fill=Y)

root.mainloop()
